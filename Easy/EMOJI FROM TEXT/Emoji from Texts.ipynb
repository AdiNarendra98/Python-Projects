# %% [markdown]
# # EMOJIs From Texts

# %%
import emoji

print(emoji.emojize("Life is Cool:thumbs_up:"))
print(emoji.emojize("Plan is to make yourself a :goat:"))
# Out:
# Life is Cool👍
# Plan is to make yourself a 🐐
